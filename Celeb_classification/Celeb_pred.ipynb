# %%
! pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 9.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip '/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/star_runs1.zip'
# Out:
# Archive:  /content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/star_runs1.zip
#   inflating: detect/train2/train_batch1.jpg
# replace detect/train2/labels.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
model = YOLO('/content/detect/train4/weights/best.pt')

# %%
a = model('/content/무제.jpg')[0]

boxes = a.boxes[0]  # Boxes object for bounding box outputs
masks = a.masks  # Masks object for segmentation masks outputs
keypoints = a.keypoints  # Keypoints object for pose outputs
probs = a.probs  # Probs object for classification outputs
a.save(filename='1_detect.jpg') # save to disk
# result.save_crop(save_dir='/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/results'+f'{num}.jpg')
# Out:
# image 1/1 /content/무제.jpg: 640x512 1 트와이스 지효, 545.0ms
# Speed: 4.3ms preprocess, 545.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
# '1_detect.jpg'

# %%
# image_list=[]
# folder='H:\내 드라이브\객체인식_3조\데이터\레드벨벳웬디\수정본'
# file_list=os.listdir(folder)
# for file in file_list:
#     image_list.append(os.path.join(folder,file))
results = model('/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/NewJeans (뉴진스) \'ETA\' Official MV.mp4',stream=True)

# %%
for num,result in enumerate(results):
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    # result.show()  # display to screen
    result.save(filename=f'{num}.jpg')  # save to disk

    result.save_crop(save_dir='/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/results'+f'{num}.jpg')
    print('save',f'{num}')
