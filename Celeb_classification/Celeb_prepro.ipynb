# %% [markdown]
# # 스타 사진 데이터 전처리
# - 남자 아이돌 100명, 여자 아이돌 100명, 기타 스타 10명
# - 스타당 500개 이미지 수집 후 단체 사진이거나 마스크 사진 검수 후 삭제함
# - 640 X 640 리사이즈 및 패딩
# - YOLO WORLD 모델로 얼굴 Bounding Box 좌표 출력

# %% [markdown]
# ## 1. 이미지 리사이즈

# %%
import os
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import tensorflow as tf
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive') # 구글 드라이브 마운트
# Out:
# Mounted at /content/drive

# %%
# 이미지 불러오기
folder_path = '/content/drive/MyDrive/Colab Notebooks/PJ4_최애티콘/star_image'
label_names = os.listdir(folder_path) # 폴더명
# label_names.remove('.DS_Store') # Mac용
print(label_names)

# %%
dataset = {} # {'스타명': 경로/파일명.jpg}
for label in os.listdir(folder_path):
    if label != '.DS_Store': # Mac용
        sub_path = folder_path+'/'+label+'/'
        dataset[label] = []
        for filename in os.listdir(sub_path):
            if filename != '.DS_Store': # Mac용
                dataset[label].append(sub_path+filename)

# %%
a = dataset['naver_에스파 카리나'][0]
print(a[64:])
print(a)
# Out:
# naver_에스파 카리나/90.jpg
# /content/drive/MyDrive/Colab Notebooks/PJ4_최애티콘/star_image/naver_에스파 카리나/90.jpg

# %% [markdown]
# ### 이미지 리사이즈&패딩

# %%
def resize_img(img_path, img_size=640): # resize 함수
    global img_re

    img = cv2.imread(img_path)

    if img is not None:
        if (img.shape[1] > img.shape[0]):
            ratio = img_size/img.shape[1]
        else:
            ratio = img_size/img.shape[0]

        img = cv2.resize(img, dsize=(0, 0), fx=ratio, fy=ratio, interpolation=cv2.INTER_LINEAR)

        # 그림 주변에 검은색으로 칠하기
        w, h = img.shape[1], img.shape[0]

        dw = (img_size-w)/2 # img_size와 w의 차이
        dh = (img_size-h)/2 # img_size와 h의 차이

        M = np.float32([[1,0,dw], [0,1,dh]])  #(2*3 이차원 행렬)
        img_re = cv2.warpAffine(img, M, (640, 640)) #이동변환
    return img_re

# %% [markdown]
# ### 이미지 저장

# %%
if not os.path.exists('resized'): #경로가 없으면
    os.mkdir('resized') # resized 폴더 생성
    for label, img_paths in dataset.items(): # resized > 가수명 폴더 생성
        os.mkdir(f'resized/{label}')
else:
    pass

for label, img_paths in dataset.items():
    for img_path in img_paths:
        img_re = resize_img(img_path)
        cv2.imwrite(f'resized/{img_path[64:]}', img_re) # resized/{가수명}/{파일명} 저장

# %% [markdown]
# ## 2. YOLO-WORLD Bounding Box 추출
# - [YOLO-WORLD](https://github.com/AILab-CVC/YOLO-World) 활용해 스타 사진의 Face Detection
# - [스타 리스트](https://docs.google.com/spreadsheets/d/13ni1cFJ_IeJZuY2Fb2H6pioZMOPeCSEjV40H0a-bEos/edit?usp=drive_link)

# %% [markdown]
# ### YOLO-WORLD 불러오기

# %%
# !git clone --recursive https://github.com/AILab-CVC/YOLO-World
# %cd YOLO-World/
# Out:
# Cloning into 'YOLO-World'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 300 (delta 74), reused 50 (delta 50), pack-reused 203
# Receiving objects: 100% (300/300), 538.38 KiB | 9.28 MiB/s, done.
# Resolving deltas: 100% (139/139), done.
# Submodule 'third_party/mmyolo' (https://github.com/onuralpszr/mmyolo.git) registered for path 'third_party/mmyolo'
# Cloning into '/content/YOLO-World/third_party/mmyolo'...
# remote: Enumerating objects: 4944, done.
# remote: Counting objects: 100% (1412/1412), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 4944 (delta 1203), reused 1128 (delta 1124), pack-reused 3532
# Receiving objects: 100% (4944/4944), 3.59 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (3195/3195), done.
# Submodule path 'third_party/mmyolo': checked out '4d97b3a06609dba94b8ec584be2f2029cfdb7519'
# /content/YOLO-World

# %%
import os
# Install certain version of requests,tqdm,rich for openxlab (fix for yolo_world)
# Install mmcv before avoding compiling of mmcv and shortining waiting time installs "whl" file
if 'COLAB_GPU' in os.environ:
  # !pip install requests==2.28.2 tqdm==4.65.0 rich==13.4.2
  # %pip install -U openmim
  # !mim install "mmengine>=0.7.0"
  # !mim install "mmcv"
else:
  # !pip install torch wheel requests==2.28.2 tqdm==4.65.0 rich==13.4.2


# !pip install -e . -vv
# Out:
# Collecting requests==2.28.2
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.8 MB/s eta 0:00:00
# Collecting tqdm==4.65.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.9 MB/s eta 0:00:00
# Collecting rich==13.4.2
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.28.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.28.2) (3.6)
# Collecting urllib3<1.27,>=1.21.1 (from requests==2.28.2)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.28.2) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.4.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.4.2) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich==13.4.2) (0.1.2)
# Installing collected packages: urllib3, tqdm, rich, requests
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.0
#     Uninstalling rich-13.7.0:
#       Successfully uninstalled rich-13.7.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.28.2 which is incompatible.
# yfinance 0.2.36 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# Successfully installed requests-2.28.2 rich-13.4.2 tqdm-4.65.0 urllib3-1.26.18
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 843.2 kB/s eta 0:00:00
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.7)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.5.2)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (4.65.0)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.0.34-py3-none-any.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.25.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 21.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 61.1 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 10.9 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.14.0.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.0/443.0 kB 39.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.21)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112371 sha256=d11e377d54541dc81ab82acd20dea09251a7d517760f3fbb4f1bbfb4cb60e093
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.14.0-py3-none-any.whl size=535289 sha256=7ee593fcbb554b3ea97ed9f2366c6a5e624dd3932476ed00e1921a05cba700c0
#   Stored in directory: /root/.cache/pip/wheels/16/3c/68/b7eab618d9f1d5e7d386296f1e07e2cf36aaa1eb5161885038
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31409 sha256=8081fbc9bb1ff4ac76c9de56fbd479cf164db3feda1b40f27b6e386650a68837
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: crcmod, setuptools, pycryptodome, ordered-set, jmespath, colorama, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# cvxpy 1.3.3 requires setuptools>65.5.1, but you have setuptools 60.2.0 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.14.0 aliyun-python-sdk-kms-2.16.2 colorama-0.4.6 crcmod-1.7 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.0.34 ordered-set-4.1.0 oss2-2.17.0 pycryptodome-3.20.0 setuptools-60.2.0
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmengine>=0.7.0
#   Downloading mmengine-0.10.3-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 5.6 MB/s eta 0:00:00
# Collecting addict (from mmengine>=0.7.0)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.7.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.7.0) (1.25.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.7.0) (6.0.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.7.0) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.7.0) (2.4.0)
# Collecting yapf (from mmengine>=0.7.0)
#   Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.7.0) (4.8.0.76)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.7.0) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.7.0) (2.16.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine>=0.7.0) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine>=0.7.0) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine>=0.7.0) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmengine>=0.7.0) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.7.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.7.0) (1.16.0)
# Installing collected packages: addict, yapf, mmengine
# Successfully installed addict-2.4.0 mmengine-0.10.3 yapf-0.40.2
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmcv
#   Downloading https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/mmcv-2.1.0-cp310-cp310-manylinux1_x86_64.whl (94.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from mmcv) (0.10.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv) (23.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv) (9.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv) (6.0.1)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.1.0
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-build-tracker-_zqepz_m
# Initialized build tracking at /tmp/pip-build-tracker-_zqepz_m
# Created build tracker: /tmp/pip-build-tracker-_zqepz_m
# Entered build tracker: /tmp/pip-build-tracker-_zqepz_m
# Created temporary directory: /tmp/pip-install-c73d_chw
# Created temporary directory: /tmp/pip-ephem-wheel-cache-flsq4c01
# Obtaining file:///content/YOLO-World
#   Added file:///content/YOLO-World to build tracker '/tmp/pip-build-tracker-_zqepz_m'
#   Created temporary directory: /tmp/pip-build-env-efsg8t29
#   Running command pip subprocess to install build dependencies
#   Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
#   Collecting setuptools
#     Downloading setuptools-69.1.1-py3-none-any.whl (819 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 5.9 MB/s eta 0:00:00
#   Collecting wheel
#     Downloading wheel-0.42.0-py3-none-any.whl (65 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 6.3 MB/s eta 0:00:00
#   Collecting torch
#     Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 881.3 kB/s eta 0:00:00
#   Collecting filelock (from torch)
#     Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
#   Collecting typing-extensions>=4.8.0 (from torch)
#     Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
#   Collecting sympy (from torch)
#     Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 73.8 MB/s eta 0:00:00
#   Collecting networkx (from torch)
#     Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.3 MB/s eta 0:00:00
#   Collecting jinja2 (from torch)
#     Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 12.8 MB/s eta 0:00:00
#   Collecting fsspec (from torch)
#     Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 14.0 MB/s eta 0:00:00
#   Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#     Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 35.0 MB/s eta 0:00:00
#   Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#     Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.4 MB/s eta 0:00:00
#   Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#     Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 51.3 MB/s eta 0:00:00
#   Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#     Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
#   Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#     Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#   Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#     Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.8 MB/s eta 0:00:00
#   Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#     Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.1 MB/s eta 0:00:00
#   Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#     Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.8 MB/s eta 0:00:00
#   Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#     Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.6 MB/s eta 0:00:00
#   Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#     Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.3 MB/s eta 0:00:00
#   Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#     Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.8 MB/s eta 0:00:00
#   Collecting triton==2.2.0 (from torch)
#     Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 6.6 MB/s eta 0:00:00
#   Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#     Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 54.7 MB/s eta 0:00:00
#   Collecting MarkupSafe>=2.0 (from jinja2->torch)
#     Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
#   Collecting mpmath>=0.19 (from sympy->torch)
#     Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#        ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 39.0 MB/s eta 0:00:00
#   Installing collected packages: mpmath, wheel, typing-extensions, sympy, setuptools, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch
#     Creating /tmp/pip-build-env-efsg8t29/overlay/local/bin
#     changing mode of /tmp/pip-build-env-efsg8t29/overlay/local/bin/wheel to 755
#     changing mode of /tmp/pip-build-env-efsg8t29/overlay/local/bin/isympy to 755
#     changing mode of /tmp/pip-build-env-efsg8t29/overlay/local/bin/convert-caffe2-to-onnx to 755
#     changing mode of /tmp/pip-build-env-efsg8t29/overlay/local/bin/convert-onnx-to-caffe2 to 755
#     changing mode of /tmp/pip-build-env-efsg8t29/overlay/local/bin/torchrun to 755
#   ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
#   ipython 7.34.0 requires jedi>=0.16, which is not installed.
#   gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.2.0 which is incompatible.
#   openxlab 0.0.34 requires setuptools~=60.2.0, but you have setuptools 69.1.1 which is incompatible.
#   torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
#   torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
#   torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
#   torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.2.1 which is incompatible.
#   Successfully installed MarkupSafe-2.1.5 filelock-3.13.1 fsspec-2024.2.0 jinja2-3.1.3 mpmath-1.3.0 networkx-3.2.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 setuptools-69.1.1 sympy-1.12 torch-2.2.1 triton-2.2.0 typing-extensions-4.10.0 wheel-0.42.0
#   Installing build dependencies ... done
#   Running command Checking if build backend supports build_editable
#   Checking if build backend supports build_editable ... done
#   Running command Getting requirements to build editable
#   running egg_info
#   creating yolo_world.egg-info
#   writing yolo_world.egg-info/PKG-INFO
#   writing dependency_links to yolo_world.egg-info/dependency_links.txt
#   writing requirements to yolo_world.egg-info/requires.txt
#   writing top-level names to yolo_world.egg-info/top_level.txt
#   writing manifest file 'yolo_world.egg-info/SOURCES.txt'
#   reading manifest file 'yolo_world.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file 'yolo_world.egg-info/SOURCES.txt'
#   Getting requirements to build editable ... done
#   Created temporary directory: /tmp/pip-modern-metadata-045yqz8k
#   Running command Preparing editable metadata (pyproject.toml)
#   running dist_info
#   creating /tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info
#   writing /tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/requires.txt
#   writing top-level names to /tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-modern-metadata-045yqz8k/yolo_world.egg-info/SOURCES.txt'
#   creating '/tmp/pip-modern-metadata-045yqz8k/yolo_world-0.1.0.dist-info'
#   Preparing editable metadata (pyproject.toml) ... done
#   Source in /content/YOLO-World has version 0.1.0, which satisfies requirement yolo_world==0.1.0 from file:///content/YOLO-World
#   Removed yolo_world==0.1.0 from file:///content/YOLO-World from build tracker '/tmp/pip-build-tracker-_zqepz_m'
# Collecting mmyolo@ git+https://github.com/onuralpszr/mmyolo.git (from yolo_world==0.1.0)
#   Cloning https://github.com/onuralpszr/mmyolo.git to /tmp/pip-install-c73d_chw/mmyolo_f2cbbb138e7045b2ad6447f894481ffa
#   Running command git version
#   git version 2.34.1
#   Running command git clone --filter=blob:none --verbose --progress https://github.com/onuralpszr/mmyolo.git /tmp/pip-install-c73d_chw/mmyolo_f2cbbb138e7045b2ad6447f894481ffa
#   Cloning into '/tmp/pip-install-c73d_chw/mmyolo_f2cbbb138e7045b2ad6447f894481ffa'...
#   POST git-upload-pack (175 bytes)
#   POST git-upload-pack (322 bytes)
#   remote: Enumerating objects: 2870, done.
#   remote: Counting objects:   0% (1/576)
#   remote: Counting objects:   1% (6/576)
#   remote: Counting objects:   2% (12/576)
#   remote: Counting objects:   3% (18/576)
#   remote: Counting objects:   4% (24/576)
#   remote: Counting objects:   5% (29/576)
#   remote: Counting objects:   6% (35/576)
#   remote: Counting objects:   7% (41/576)
#   remote: Counting objects:   8% (47/576)
#   remote: Counting objects:   9% (52/576)
#   remote: Counting objects:  10% (58/576)
#   remote: Counting objects:  11% (64/576)
#   remote: Counting objects:  12% (70/576)
#   remote: Counting objects:  13% (75/576)
#   remote: Counting objects:  14% (81/576)
#   remote: Counting objects:  15% (87/576)
#   remote: Counting objects:  16% (93/576)
#   remote: Counting objects:  17% (98/576)
#   remote: Counting objects:  18% (104/576)
#   remote: Counting objects:  19% (110/576)
#   remote: Counting objects:  20% (116/576)
#   remote: Counting objects:  21% (121/576)
#   remote: Counting objects:  22% (127/576)
#   remote: Counting objects:  23% (133/576)
#   remote: Counting objects:  24% (139/576)
#   remote: Counting objects:  25% (144/576)
#   remote: Counting objects:  26% (150/576)
#   remote: Counting objects:  27% (156/576)
#   remote: Counting objects:  28% (162/576)
#   remote: Counting objects:  29% (168/576)
#   remote: Counting objects:  30% (173/576)
#   remote: Counting objects:  31% (179/576)
#   remote: Counting objects:  32% (185/576)
#   remote: Counting objects:  33% (191/576)
#   remote: Counting objects:  34% (196/576)
#   remote: Counting objects:  35% (202/576)
#   remote: Counting objects:  36% (208/576)
#   remote: Counting objects:  37% (214/576)
#   remote: Counting objects:  38% (219/576)
#   remote: Counting objects:  39% (225/576)
#   remote: Counting objects:  40% (231/576)
#   remote: Counting objects:  41% (237/576)
#   remote: Counting objects:  42% (242/576)
#   remote: Counting objects:  43% (248/576)
#   remote: Counting objects:  44% (254/576)
#   remote: Counting objects:  45% (260/576)
#   remote: Counting objects:  46% (265/576)
#   remote: Counting objects:  47% (271/576)
#   remote: Counting objects:  48% (277/576)
#   remote: Counting objects:  49% (283/576)
#   remote: Counting objects:  50% (288/576)
#   remote: Counting objects:  51% (294/576)
#   remote: Counting objects:  52% (300/576)
#   remote: Counting objects:  53% (306/576)
#   remote: Counting objects:  54% (312/576)
#   remote: Counting objects:  55% (317/576)
#   remote: Counting objects:  56% (323/576)
#   remote: Counting objects:  57% (329/576)
#   remote: Counting objects:  58% (335/576)
#   remote: Counting objects:  59% (340/576)
#   remote: Counting objects:  60% (346/576)
#   remote: Counting objects:  61% (352/576)
#   remote: Counting objects:  62% (358/576)
#   remote: Counting objects:  63% (363/576)
#   remote: Counting objects:  64% (369/576)
#   remote: Counting objects:  65% (375/576)
#   remote: Counting objects:  66% (381/576)
#   remote: Counting objects:  67% (386/576)
#   remote: Counting objects:  68% (392/576)
#   remote: Counting objects:  69% (398/576)
#   remote: Counting objects:  70% (404/576)
#   remote: Counting objects:  71% (409/576)
#   remote: Counting objects:  72% (415/576)
#   remote: Counting objects:  73% (421/576)
#   remote: Counting objects:  74% (427/576)
#   remote: Counting objects:  75% (432/576)
#   remote: Counting objects:  76% (438/576)
#   remote: Counting objects:  77% (444/576)
#   remote: Counting objects:  78% (450/576)
#   remote: Counting objects:  79% (456/576)
#   remote: Counting objects:  80% (461/576)
#   remote: Counting objects:  81% (467/576)
#   remote: Counting objects:  82% (473/576)
#   remote: Counting objects:  83% (479/576)
#   remote: Counting objects:  84% (484/576)
#   remote: Counting objects:  85% (490/576)
#   remote: Counting objects:  86% (496/576)
#   remote: Counting objects:  87% (502/576)
#   remote: Counting objects:  88% (507/576)
#   remote: Counting objects:  89% (513/576)
#   remote: Counting objects:  90% (519/576)
#   remote: Counting objects:  91% (525/576)
#   remote: Counting objects:  92% (530/576)
#   remote: Counting objects:  93% (536/576)
#   remote: Counting objects:  94% (542/576)
#   remote: Counting objects:  95% (548/576)
#   remote: Counting objects:  96% (553/576)
#   remote: Counting objects:  97% (559/576)
#   remote: Counting objects:  98% (565/576)
#   remote: Counting objects:  99% (571/576)
#   remote: Counting objects: 100% (576/576)
#   remote: Counting objects: 100% (576/576), done.
#   remote: Compressing objects:   0% (1/104)
#   remote: Compressing objects:   1% (2/104)
#   remote: Compressing objects:   2% (3/104)
#   remote: Compressing objects:   3% (4/104)
#   remote: Compressing objects:   4% (5/104)
#   remote: Compressing objects:   5% (6/104)
#   remote: Compressing objects:   6% (7/104)
#   remote: Compressing objects:   7% (8/104)
#   remote: Compressing objects:   8% (9/104)
#   remote: Compressing objects:   9% (10/104)
#   remote: Compressing objects:  10% (11/104)
#   remote: Compressing objects:  11% (12/104)
#   remote: Compressing objects:  12% (13/104)
#   remote: Compressing objects:  13% (14/104)
#   remote: Compressing objects:  14% (15/104)
#   remote: Compressing objects:  15% (16/104)
#   remote: Compressing objects:  16% (17/104)
#   remote: Compressing objects:  17% (18/104)
#   remote: Compressing objects:  18% (19/104)
#   remote: Compressing objects:  19% (20/104)
#   remote: Compressing objects:  20% (21/104)
#   remote: Compressing objects:  21% (22/104)
#   remote: Compressing objects:  22% (23/104)
#   remote: Compressing objects:  23% (24/104)
#   remote: Compressing objects:  24% (25/104)
#   remote: Compressing objects:  25% (26/104)
#   remote: Compressing objects:  26% (28/104)
#   remote: Compressing objects:  27% (29/104)
#   remote: Compressing objects:  28% (30/104)
#   remote: Compressing objects:  29% (31/104)
#   remote: Compressing objects:  30% (32/104)
#   remote: Compressing objects:  31% (33/104)
#   remote: Compressing objects:  32% (34/104)
#   remote: Compressing objects:  33% (35/104)
#   remote: Compressing objects:  34% (36/104)
#   remote: Compressing objects:  35% (37/104)
#   remote: Compressing objects:  36% (38/104)
#   remote: Compressing objects:  37% (39/104)
#   remote: Compressing objects:  38% (40/104)
#   remote: Compressing objects:  39% (41/104)
#   remote: Compressing objects:  40% (42/104)
#   remote: Compressing objects:  41% (43/104)
#   remote: Compressing objects:  42% (44/104)
#   remote: Compressing objects:  43% (45/104)
#   remote: Compressing objects:  44% (46/104)
#   remote: Compressing objects:  45% (47/104)
#   remote: Compressing objects:  46% (48/104)
#   remote: Compressing objects:  47% (49/104)
#   remote: Compressing objects:  48% (50/104)
#   remote: Compressing objects:  49% (51/104)
#   remote: Compressing objects:  50% (52/104)
#   remote: Compressing objects:  51% (54/104)
#   remote: Compressing objects:  52% (55/104)
#   remote: Compressing objects:  53% (56/104)
#   remote: Compressing objects:  54% (57/104)
#   remote: Compressing objects:  55% (58/104)
#   remote: Compressing objects:  56% (59/104)
#   remote: Compressing objects:  57% (60/104)
#   remote: Compressing objects:  58% (61/104)
#   remote: Compressing objects:  59% (62/104)
#   remote: Compressing objects:  60% (63/104)
#   remote: Compressing objects:  61% (64/104)
#   remote: Compressing objects:  62% (65/104)
#   remote: Compressing objects:  63% (66/104)
#   remote: Compressing objects:  64% (67/104)
#   remote: Compressing objects:  65% (68/104)
#   remote: Compressing objects:  66% (69/104)
#   remote: Compressing objects:  67% (70/104)
#   remote: Compressing objects:  68% (71/104)
#   remote: Compressing objects:  69% (72/104)
#   remote: Compressing objects:  70% (73/104)
#   remote: Compressing objects:  71% (74/104)
#   remote: Compressing objects:  72% (75/104)
#   remote: Compressing objects:  73% (76/104)
#   remote: Compressing objects:  74% (77/104)
#   remote: Compressing objects:  75% (78/104)
#   remote: Compressing objects:  76% (80/104)
#   remote: Compressing objects:  77% (81/104)
#   remote: Compressing objects:  78% (82/104)
#   remote: Compressing objects:  79% (83/104)
#   remote: Compressing objects:  80% (84/104)
#   remote: Compressing objects:  81% (85/104)
#   remote: Compressing objects:  82% (86/104)
#   remote: Compressing objects:  83% (87/104)
#   remote: Compressing objects:  84% (88/104)
#   remote: Compressing objects:  85% (89/104)
#   remote: Compressing objects:  86% (90/104)
#   remote: Compressing objects:  87% (91/104)
#   remote: Compressing objects:  88% (92/104)
#   remote: Compressing objects:  89% (93/104)
#   remote: Compressing objects:  90% (94/104)
#   remote: Compressing objects:  91% (95/104)
#   remote: Compressing objects:  92% (96/104)
#   remote: Compressing objects:  93% (97/104)
#   remote: Compressing objects:  94% (98/104)
#   remote: Compressing objects:  95% (99/104)
#   remote: Compressing objects:  96% (100/104)
#   remote: Compressing objects:  97% (101/104)
#   remote: Compressing objects:  98% (102/104)
#   remote: Compressing objects:  99% (103/104)
#   remote: Compressing objects: 100% (104/104)
#   remote: Compressing objects: 100% (104/104), done.
#   Receiving objects:   0% (1/2870)
#   Receiving objects:   1% (29/2870)
#   Receiving objects:   2% (58/2870)
#   Receiving objects:   3% (87/2870)
#   Receiving objects:   4% (115/2870)
#   Receiving objects:   5% (144/2870)
#   Receiving objects:   6% (173/2870)
#   Receiving objects:   7% (201/2870)
#   Receiving objects:   8% (230/2870)
#   Receiving objects:   9% (259/2870)
#   Receiving objects:  10% (287/2870)
#   Receiving objects:  11% (316/2870)
#   Receiving objects:  12% (345/2870)
#   Receiving objects:  13% (374/2870)
#   Receiving objects:  14% (402/2870)
#   Receiving objects:  15% (431/2870)
#   Receiving objects:  16% (460/2870)
#   Receiving objects:  17% (488/2870)
#   Receiving objects:  18% (517/2870)
#   Receiving objects:  19% (546/2870)
#   Receiving objects:  20% (574/2870)
#   Receiving objects:  21% (603/2870)
#   Receiving objects:  22% (632/2870)
#   Receiving objects:  23% (661/2870)
#   Receiving objects:  24% (689/2870)
#   Receiving objects:  25% (718/2870)
#   Receiving objects:  26% (747/2870)
#   Receiving objects:  27% (775/2870)
#   Receiving objects:  28% (804/2870)
#   Receiving objects:  29% (833/2870)
#   Receiving objects:  30% (861/2870)
#   Receiving objects:  31% (890/2870)
#   Receiving objects:  32% (919/2870)
#   Receiving objects:  33% (948/2870)
#   Receiving objects:  34% (976/2870)
#   Receiving objects:  35% (1005/2870)
#   Receiving objects:  36% (1034/2870)
#   Receiving objects:  37% (1062/2870)
#   Receiving objects:  38% (1091/2870)
#   Receiving objects:  39% (1120/2870)
#   Receiving objects:  40% (1148/2870)
#   Receiving objects:  41% (1177/2870)
#   Receiving objects:  42% (1206/2870)
#   Receiving objects:  43% (1235/2870)
#   Receiving objects:  44% (1263/2870)
#   Receiving objects:  45% (1292/2870)
#   Receiving objects:  46% (1321/2870)
#   Receiving objects:  47% (1349/2870)
#   Receiving objects:  48% (1378/2870)
#   Receiving objects:  49% (1407/2870)
#   Receiving objects:  50% (1435/2870)
#   Receiving objects:  51% (1464/2870)
#   Receiving objects:  52% (1493/2870)
#   Receiving objects:  53% (1522/2870)
#   Receiving objects:  54% (1550/2870)
#   Receiving objects:  55% (1579/2870)
#   Receiving objects:  56% (1608/2870)
#   Receiving objects:  57% (1636/2870)
#   Receiving objects:  58% (1665/2870)
#   Receiving objects:  59% (1694/2870)
#   Receiving objects:  60% (1722/2870)
#   Receiving objects:  61% (1751/2870)
#   Receiving objects:  62% (1780/2870)
#   Receiving objects:  63% (1809/2870)
#   Receiving objects:  64% (1837/2870)
#   Receiving objects:  65% (1866/2870)
#   Receiving objects:  66% (1895/2870)
#   Receiving objects:  67% (1923/2870)
#   Receiving objects:  68% (1952/2870)
#   Receiving objects:  69% (1981/2870)
#   Receiving objects:  70% (2009/2870)
#   Receiving objects:  71% (2038/2870)
#   Receiving objects:  72% (2067/2870)
#   Receiving objects:  73% (2096/2870)
#   Receiving objects:  74% (2124/2870)
#   Receiving objects:  75% (2153/2870)
#   Receiving objects:  76% (2182/2870)
#   Receiving objects:  77% (2210/2870)
#   Receiving objects:  78% (2239/2870)
#   Receiving objects:  79% (2268/2870)
#   Receiving objects:  80% (2296/2870)
#   remote: Total 2870 (delta 500), reused 476 (delta 472), pack-reused 2294
#   Receiving objects:  81% (2325/2870)
#   Receiving objects:  82% (2354/2870)
#   Receiving objects:  83% (2383/2870)
#   Receiving objects:  84% (2411/2870)
#   Receiving objects:  85% (2440/2870)
#   Receiving objects:  86% (2469/2870)
#   Receiving objects:  87% (2497/2870)
#   Receiving objects:  88% (2526/2870)
#   Receiving objects:  89% (2555/2870)
#   Receiving objects:  90% (2583/2870)
#   Receiving objects:  91% (2612/2870)
#   Receiving objects:  92% (2641/2870)
#   Receiving objects:  93% (2670/2870)
#   Receiving objects:  94% (2698/2870)
#   Receiving objects:  95% (2727/2870)
#   Receiving objects:  96% (2756/2870)
#   Receiving objects:  97% (2784/2870)
#   Receiving objects:  98% (2813/2870)
#   Receiving objects:  99% (2842/2870)
#   Receiving objects: 100% (2870/2870)
#   Receiving objects: 100% (2870/2870), 455.06 KiB | 7.71 MiB/s, done.
#   Resolving deltas:   0% (0/1679)
#   Resolving deltas:   1% (17/1679)
#   Resolving deltas:   2% (34/1679)
#   Resolving deltas:   3% (51/1679)
#   Resolving deltas:   4% (68/1679)
#   Resolving deltas:   5% (84/1679)
#   Resolving deltas:   6% (101/1679)
#   Resolving deltas:   7% (118/1679)
#   Resolving deltas:   8% (135/1679)
#   Resolving deltas:   9% (152/1679)
#   Resolving deltas:  10% (168/1679)
#   Resolving deltas:  11% (185/1679)
#   Resolving deltas:  12% (202/1679)
#   Resolving deltas:  13% (219/1679)
#   Resolving deltas:  14% (236/1679)
#   Resolving deltas:  15% (252/1679)
#   Resolving deltas:  16% (269/1679)
#   Resolving deltas:  17% (286/1679)
#   Resolving deltas:  18% (303/1679)
#   Resolving deltas:  19% (320/1679)
#   Resolving deltas:  20% (336/1679)
#   Resolving deltas:  21% (353/1679)
#   Resolving deltas:  22% (370/1679)
#   Resolving deltas:  23% (387/1679)
#   Resolving deltas:  24% (403/1679)
#   Resolving deltas:  25% (420/1679)
#   Resolving deltas:  26% (437/1679)
#   Resolving deltas:  27% (454/1679)
#   Resolving deltas:  28% (471/1679)
#   Resolving deltas:  29% (487/1679)
#   Resolving deltas:  30% (504/1679)
#   Resolving deltas:  31% (521/1679)
#   Resolving deltas:  32% (538/1679)
#   Resolving deltas:  33% (555/1679)
#   Resolving deltas:  34% (571/1679)
#   Resolving deltas:  35% (588/1679)
#   Resolving deltas:  36% (605/1679)
#   Resolving deltas:  37% (622/1679)
#   Resolving deltas:  38% (639/1679)
#   Resolving deltas:  39% (655/1679)
#   Resolving deltas:  40% (672/1679)
#   Resolving deltas:  41% (689/1679)
#   Resolving deltas:  42% (706/1679)
#   Resolving deltas:  43% (722/1679)
#   Resolving deltas:  44% (739/1679)
#   Resolving deltas:  45% (756/1679)
#   Resolving deltas:  46% (773/1679)
#   Resolving deltas:  47% (790/1679)
#   Resolving deltas:  48% (806/1679)
#   Resolving deltas:  49% (823/1679)
#   Resolving deltas:  50% (840/1679)
#   Resolving deltas:  51% (857/1679)
#   Resolving deltas:  52% (874/1679)
#   Resolving deltas:  53% (890/1679)
#   Resolving deltas:  54% (907/1679)
#   Resolving deltas:  55% (924/1679)
#   Resolving deltas:  56% (941/1679)
#   Resolving deltas:  57% (958/1679)
#   Resolving deltas:  58% (974/1679)
#   Resolving deltas:  59% (991/1679)
#   Resolving deltas:  60% (1008/1679)
#   Resolving deltas:  61% (1025/1679)
#   Resolving deltas:  62% (1041/1679)
#   Resolving deltas:  63% (1058/1679)
#   Resolving deltas:  64% (1075/1679)
#   Resolving deltas:  65% (1092/1679)
#   Resolving deltas:  66% (1109/1679)
#   Resolving deltas:  67% (1125/1679)
#   Resolving deltas:  68% (1142/1679)
#   Resolving deltas:  69% (1159/1679)
#   Resolving deltas:  70% (1176/1679)
#   Resolving deltas:  71% (1193/1679)
#   Resolving deltas:  72% (1209/1679)
#   Resolving deltas:  73% (1226/1679)
#   Resolving deltas:  74% (1243/1679)
#   Resolving deltas:  75% (1260/1679)
#   Resolving deltas:  76% (1277/1679)
#   Resolving deltas:  77% (1293/1679)
#   Resolving deltas:  78% (1310/1679)
#   Resolving deltas:  79% (1327/1679)
#   Resolving deltas:  80% (1344/1679)
#   Resolving deltas:  81% (1360/1679)
#   Resolving deltas:  82% (1377/1679)
#   Resolving deltas:  83% (1394/1679)
#   Resolving deltas:  84% (1411/1679)
#   Resolving deltas:  85% (1428/1679)
#   Resolving deltas:  86% (1444/1679)
#   Resolving deltas:  87% (1461/1679)
#   Resolving deltas:  88% (1478/1679)
#   Resolving deltas:  89% (1495/1679)
#   Resolving deltas:  90% (1512/1679)
#   Resolving deltas:  91% (1528/1679)
#   Resolving deltas:  92% (1545/1679)
#   Resolving deltas:  93% (1562/1679)
#   Resolving deltas:  94% (1579/1679)
#   Resolving deltas:  95% (1596/1679)
#   Resolving deltas:  96% (1612/1679)
#   Resolving deltas:  97% (1629/1679)
#   Resolving deltas:  98% (1646/1679)
#   Resolving deltas:  99% (1663/1679)
#   Resolving deltas: 100% (1679/1679)
#   Resolving deltas: 100% (1679/1679), done.
#   Running command git rev-parse HEAD
#   4d97b3a06609dba94b8ec584be2f2029cfdb7519
#   Resolved https://github.com/onuralpszr/mmyolo.git to commit 4d97b3a06609dba94b8ec584be2f2029cfdb7519
#   Running command git rev-parse HEAD
#   4d97b3a06609dba94b8ec584be2f2029cfdb7519
#   Added mmyolo@ git+https://github.com/onuralpszr/mmyolo.git from git+https://github.com/onuralpszr/mmyolo.git (from yolo_world==0.1.0) to build tracker '/tmp/pip-build-tracker-_zqepz_m'
#   Running setup.py (path:/tmp/pip-install-c73d_chw/mmyolo_f2cbbb138e7045b2ad6447f894481ffa/setup.py) egg_info for package mmyolo
#   Created temporary directory: /tmp/pip-pip-egg-info-on7obex4
#   Running command python setup.py egg_info
#   No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
#   running egg_info
#   creating /tmp/pip-pip-egg-info-on7obex4/mmyolo.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-on7obex4/mmyolo.egg-info/SOURCES.txt'
#   warning: no files found matching 'mmyolo/VERSION'
#   warning: no files found matching 'mmyolo/.mim/model-index.yml'
#   warning: no files found matching 'mmyolo/.mim/demo/*/*'
#   warning: no files found matching '*.py' under directory 'mmyolo/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmyolo/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmyolo/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmyolo/.mim/tools'
#   writing manifest file '/tmp/pip-pip-egg-info-on7obex4/mmyolo.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
#   Source in /tmp/pip-install-c73d_chw/mmyolo_f2cbbb138e7045b2ad6447f894481ffa has version 0.6.0, which satisfies requirement mmyolo@ git+https://github.com/onuralpszr/mmyolo.git from git+https://github.com/onuralpszr/mmyolo.git (from yolo_world==0.1.0)
#   Removed mmyolo@ git+https://github.com/onuralpszr/mmyolo.git from git+https://github.com/onuralpszr/mmyolo.git (from yolo_world==0.1.0) from build tracker '/tmp/pip-build-tracker-_zqepz_m'
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (0.42.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (0.16.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (4.37.2)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (0.15.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (1.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from yolo_world==0.1.0) (4.8.0.76)
# 1 location(s) to search for versions of supervision:
# * https://pypi.org/simple/supervision/
# Fetching project page and analyzing links: https://pypi.org/simple/supervision/
# Getting page https://pypi.org/simple/supervision/
# Found index url https://pypi.org/simple/
# Looking up "https://pypi.org/simple/supervision/" in the cache
# Request header has "max_age" as 0, cache bypassed
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/supervision/ HTTP/1.1" 200 13794
# Updating cache with response from "https://pypi.org/simple/supervision/"
# etag object cached for 1209600 seconds
# Caching due to etag
# Fetched page https://pypi.org/simple/supervision/ as application/vnd.pypi.simple.v1+json
#   Found link https://files.pythonhosted.org/packages/fd/e4/94635501dc8880abadfb76a1f944cf3f138f779184a671b092df28257da2/supervision-0.1.0-py3-none-any.whl (from https://pypi.org/simple/supervision/) (requires-python:>=3.7), version: 0.1.0
# ...
#   adding 'mmyolo/.mim/configs/rtmdet/rotated/rtmdet-r_s_fast_1xb8-36e_dota.py'
#   adding 'mmyolo/.mim/configs/rtmdet/rotated/rtmdet-r_tiny_fast_1xb8-36e_dota-ms.py'
#   adding 'mmyolo/.mim/configs/rtmdet/rotated/rtmdet-r_tiny_fast_1xb8-36e_dota.py'
#   adding 'mmyolo/.mim/configs/yolov5/metafile.yml'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_l-p6-v62_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_l-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_m-p6-v62_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_m-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_n-p6-v62_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_n-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-p6-v62_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_fast_1xb12-40e_608x352_cat.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_fast_1xb12-40e_cat.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_fast_1xb12-ms-40e_cat.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_syncbn-detect_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_syncbn_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_syncbn_fast_1xb4-300e_balloon.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_s-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_x-p6-v62_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5_x-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/crowdhuman/yolov5_s-v61_8xb16-300e_ignore_crowdhuman.py'
#   adding 'mmyolo/.mim/configs/yolov5/crowdhuman/yolov5_s-v61_fast_8xb16-300e_crowdhuman.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_l-v61_syncbn_fast_8xb16-300e_coco_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_m-v61_syncbn_fast_8xb16-300e_coco_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_n-v61_syncbn_fast_8xb16-300e_coco_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_s-v61_syncbn_fast_8xb16-300e_balloon_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_s-v61_syncbn_fast_8xb16-300e_coco_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_s-v61_syncbn_fast_non_overlap_8xb16-300e_coco_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/ins_seg/yolov5_ins_x-v61_syncbn_fast_8xb16-300e_coco_instance.py'
#   adding 'mmyolo/.mim/configs/yolov5/mask_refine/yolov5_l_mask-refine-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/mask_refine/yolov5_m_mask-refine-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/mask_refine/yolov5_n_mask-refine-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/mask_refine/yolov5_s_mask-refine-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/mask_refine/yolov5_x_mask-refine-v61_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/voc/yolov5_l-v61_fast_1xb32-50e_voc.py'
#   adding 'mmyolo/.mim/configs/yolov5/voc/yolov5_m-v61_fast_1xb64-50e_voc.py'
#   adding 'mmyolo/.mim/configs/yolov5/voc/yolov5_n-v61_fast_1xb64-50e_voc.py'
#   adding 'mmyolo/.mim/configs/yolov5/voc/yolov5_s-v61_fast_1xb64-50e_voc.py'
#   adding 'mmyolo/.mim/configs/yolov5/voc/yolov5_x-v61_fast_1xb32-50e_voc.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_l_mask-refine_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_l_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_m_mask-refine_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_m_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_n_mask-refine_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_n_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_s_mask-refine_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_s_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_x_mask-refine_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov5/yolov5u/yolov5u_x_syncbn_fast_8xb16-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/metafile.yml'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_l_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_m_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_n_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_n_syncbn_fast_8xb32-400e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_s_fast_1xb12-40e_cat.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_s_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_s_syncbn_fast_8xb32-400e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_t_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_t_syncbn_fast_8xb32-400e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_v3_l_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_v3_m_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_v3_n_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_v3_s_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov6/yolov6_v3_t_syncbn_fast_8xb32-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/metafile.yml'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_d-p6_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_e-p6_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_e2e-p6_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_l_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_tiny_fast_1xb12-40e_cat.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_tiny_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_w-p6_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov7/yolov7_x_syncbn_fast_8x16b-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/metafile.yml'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_l_mask-refine_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_l_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_m_mask-refine_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_m_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_n_mask-refine_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_n_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_s_fast_1xb12-40e_cat.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_s_mask-refine_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_s_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_x_mask-refine_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolov8/yolov8_x_syncbn_fast_8xb16-500e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/metafile.yml'
#   adding 'mmyolo/.mim/configs/yolox/yolox_l_fast_8xb8-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_m_fast_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_m_fast_8xb8-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_nano_fast_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_nano_fast_8xb8-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_p5_tta.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_s_fast_1xb12-40e-rtmdet-hyp_cat.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_s_fast_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_s_fast_8xb8-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_tiny_fast_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_tiny_fast_8xb8-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/yolox_x_fast_8xb8-300e_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/pose/yolox-pose_l_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/pose/yolox-pose_m_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/pose/yolox-pose_s_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/configs/yolox/pose/yolox-pose_tiny_8xb32-300e-rtmdet-hyp_coco.py'
#   adding 'mmyolo/.mim/tools/dist_test.sh'
#   adding 'mmyolo/.mim/tools/dist_train.sh'
#   adding 'mmyolo/.mim/tools/slurm_test.sh'
#   adding 'mmyolo/.mim/tools/slurm_train.sh'
#   adding 'mmyolo/.mim/tools/test.py'
#   adding 'mmyolo/.mim/tools/train.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/benchmark.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/browse_coco_json.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/browse_dataset.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/browse_dataset_simple.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/confusion_matrix.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/dataset_analysis.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/get_flops.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/optimize_anchors.py'
#   adding 'mmyolo/.mim/tools/analysis_tools/vis_scheduler.py'
#   adding 'mmyolo/.mim/tools/dataset_converters/balloon2coco.py'
#   adding 'mmyolo/.mim/tools/dataset_converters/labelme2coco.py'
#   adding 'mmyolo/.mim/tools/dataset_converters/yolo2coco.py'
#   adding 'mmyolo/.mim/tools/dataset_converters/dota/dota_split.py'
#   adding 'mmyolo/.mim/tools/misc/coco_split.py'
#   adding 'mmyolo/.mim/tools/misc/download_dataset.py'
#   adding 'mmyolo/.mim/tools/misc/extract_subcoco.py'
#   adding 'mmyolo/.mim/tools/misc/print_config.py'
#   adding 'mmyolo/.mim/tools/misc/publish_model.py'
#   adding 'mmyolo/.mim/tools/model_converters/convert_kd_ckpt_to_student.py'
#   adding 'mmyolo/.mim/tools/model_converters/ppyoloe_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/rtmdet_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolov5_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolov5u_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolov6_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolov6_v3_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolov7_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolov8_to_mmyolo.py'
#   adding 'mmyolo/.mim/tools/model_converters/yolox_to_mmyolo.py'
#   adding 'mmyolo/datasets/__init__.py'
#   adding 'mmyolo/datasets/pose_coco.py'
#   adding 'mmyolo/datasets/utils.py'
#   adding 'mmyolo/datasets/yolov5_coco.py'
#   adding 'mmyolo/datasets/yolov5_crowdhuman.py'
#   adding 'mmyolo/datasets/yolov5_dota.py'
#   adding 'mmyolo/datasets/yolov5_voc.py'
#   adding 'mmyolo/datasets/transforms/__init__.py'
#   adding 'mmyolo/datasets/transforms/formatting.py'
#   adding 'mmyolo/datasets/transforms/keypoint_structure.py'
#   adding 'mmyolo/datasets/transforms/mix_img_transforms.py'
#   adding 'mmyolo/datasets/transforms/transforms.py'
#   adding 'mmyolo/deploy/__init__.py'
#   adding 'mmyolo/deploy/object_detection.py'
#   adding 'mmyolo/deploy/models/__init__.py'
#   adding 'mmyolo/deploy/models/dense_heads/__init__.py'
#   adding 'mmyolo/deploy/models/dense_heads/yolov5_head.py'
#   adding 'mmyolo/deploy/models/layers/__init__.py'
#   adding 'mmyolo/deploy/models/layers/bbox_nms.py'
#   adding 'mmyolo/engine/__init__.py'
#   adding 'mmyolo/engine/hooks/__init__.py'
#   adding 'mmyolo/engine/hooks/ppyoloe_param_scheduler_hook.py'
#   adding 'mmyolo/engine/hooks/switch_to_deploy_hook.py'
#   adding 'mmyolo/engine/hooks/yolov5_param_scheduler_hook.py'
#   adding 'mmyolo/engine/hooks/yolox_mode_switch_hook.py'
#   adding 'mmyolo/engine/optimizers/__init__.py'
#   adding 'mmyolo/engine/optimizers/yolov5_optim_constructor.py'
#   adding 'mmyolo/engine/optimizers/yolov7_optim_wrapper_constructor.py'
#   adding 'mmyolo/models/__init__.py'
#   adding 'mmyolo/models/backbones/__init__.py'
#   adding 'mmyolo/models/backbones/base_backbone.py'
#   adding 'mmyolo/models/backbones/csp_darknet.py'
#   adding 'mmyolo/models/backbones/csp_resnet.py'
#   adding 'mmyolo/models/backbones/cspnext.py'
#   adding 'mmyolo/models/backbones/efficient_rep.py'
#   adding 'mmyolo/models/backbones/yolov7_backbone.py'
#   adding 'mmyolo/models/data_preprocessors/__init__.py'
#   adding 'mmyolo/models/data_preprocessors/data_preprocessor.py'
#   adding 'mmyolo/models/dense_heads/__init__.py'
#   adding 'mmyolo/models/dense_heads/ppyoloe_head.py'
#   adding 'mmyolo/models/dense_heads/rtmdet_head.py'
#   adding 'mmyolo/models/dense_heads/rtmdet_ins_head.py'
#   adding 'mmyolo/models/dense_heads/rtmdet_rotated_head.py'
#   adding 'mmyolo/models/dense_heads/yolov5_head.py'
#   adding 'mmyolo/models/dense_heads/yolov5_ins_head.py'
#   adding 'mmyolo/models/dense_heads/yolov6_head.py'
#   adding 'mmyolo/models/dense_heads/yolov7_head.py'
#   adding 'mmyolo/models/dense_heads/yolov8_head.py'
#   adding 'mmyolo/models/dense_heads/yolox_head.py'
#   adding 'mmyolo/models/dense_heads/yolox_pose_head.py'
#   adding 'mmyolo/models/detectors/__init__.py'
#   adding 'mmyolo/models/detectors/yolo_detector.py'
#   adding 'mmyolo/models/layers/__init__.py'
#   adding 'mmyolo/models/layers/ema.py'
#   adding 'mmyolo/models/layers/yolo_bricks.py'
#   adding 'mmyolo/models/losses/__init__.py'
#   adding 'mmyolo/models/losses/iou_loss.py'
#   adding 'mmyolo/models/losses/oks_loss.py'
#   adding 'mmyolo/models/necks/__init__.py'
#   adding 'mmyolo/models/necks/base_yolo_neck.py'
#   adding 'mmyolo/models/necks/cspnext_pafpn.py'
#   adding 'mmyolo/models/necks/ppyoloe_csppan.py'
#   adding 'mmyolo/models/necks/yolov5_pafpn.py'
#   adding 'mmyolo/models/necks/yolov6_pafpn.py'
#   adding 'mmyolo/models/necks/yolov7_pafpn.py'
#   adding 'mmyolo/models/necks/yolov8_pafpn.py'
#   adding 'mmyolo/models/necks/yolox_pafpn.py'
#   adding 'mmyolo/models/plugins/__init__.py'
#   adding 'mmyolo/models/plugins/cbam.py'
#   adding 'mmyolo/models/task_modules/__init__.py'
#   adding 'mmyolo/models/task_modules/assigners/__init__.py'
#   adding 'mmyolo/models/task_modules/assigners/batch_atss_assigner.py'
#   adding 'mmyolo/models/task_modules/assigners/batch_dsl_assigner.py'
#   adding 'mmyolo/models/task_modules/assigners/batch_task_aligned_assigner.py'
#   adding 'mmyolo/models/task_modules/assigners/batch_yolov7_assigner.py'
#   adding 'mmyolo/models/task_modules/assigners/pose_sim_ota_assigner.py'
#   adding 'mmyolo/models/task_modules/assigners/utils.py'
#   adding 'mmyolo/models/task_modules/coders/__init__.py'
#   adding 'mmyolo/models/task_modules/coders/distance_angle_point_coder.py'
#   adding 'mmyolo/models/task_modules/coders/distance_point_bbox_coder.py'
#   adding 'mmyolo/models/task_modules/coders/yolov5_bbox_coder.py'
#   adding 'mmyolo/models/task_modules/coders/yolox_bbox_coder.py'
#   adding 'mmyolo/models/utils/__init__.py'
#   adding 'mmyolo/models/utils/misc.py'
#   adding 'mmyolo/testing/__init__.py'
#   adding 'mmyolo/testing/_utils.py'
#   adding 'mmyolo/utils/__init__.py'
#   adding 'mmyolo/utils/boxam_utils.py'
#   adding 'mmyolo/utils/collect_env.py'
#   adding 'mmyolo/utils/labelme_utils.py'
#   adding 'mmyolo/utils/large_image.py'
#   adding 'mmyolo/utils/misc.py'
#   adding 'mmyolo/utils/setup_env.py'
#   adding 'mmyolo-0.6.0.dist-info/LICENSE'
#   adding 'mmyolo-0.6.0.dist-info/METADATA'
#   adding 'mmyolo-0.6.0.dist-info/WHEEL'
#   adding 'mmyolo-0.6.0.dist-info/top_level.txt'
#   adding 'mmyolo-0.6.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
# done
#   Created wheel for mmyolo: filename=mmyolo-0.6.0-py3-none-any.whl size=453694 sha256=a11ca3c157cf98f13b5aac301c1893470c7ab48e124b60a6aabfcbfbe4f2146b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-flsq4c01/wheels/d6/7c/b8/a78624113a6f593a8251d2d1e7420373491c8c037159f5c39e
# Successfully built yolo_world mmyolo
# Installing collected packages: terminaltables, mmyolo, supervision, mmdet, mmcv-lite, yolo_world
#
#
#
#
#
#
# Successfully installed mmcv-lite-2.0.1 mmdet-3.3.0 mmyolo-0.6.0 supervision-0.18.0 terminaltables-3.1.10 yolo_world-0.1.0
# Removed build tracker: '/tmp/pip-build-tracker-_zqepz_m'

# %%
# Restart collab session (required for mmengine)
quit()

# %%
# !wget https://huggingface.co/spaces/stevengrove/YOLO-World/resolve/main/yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth?download=true
# !mv yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth?download=true yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth
# !wget https://huggingface.co/spaces/stevengrove/YOLO-World/resolve/main/configs/pretrain/yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py?download=true
# !mv yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py?download=true yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py
# !wget https://media.roboflow.com/notebooks/examples/dog.jpeg
# !cp -r yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py /content/YOLO-World/configs/pretrain/
# Out:
# --2024-02-28 09:52:19--  https://huggingface.co/spaces/stevengrove/YOLO-World/resolve/main/yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth?download=true
# Resolving huggingface.co (huggingface.co)... 65.8.178.27, 65.8.178.12, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.27|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.huggingface.co/repos/cc/e2/cce2cecbe61f2002bfd047dbb19558446e78db43c2b1c4a89071860f6eeb9a0e/c86e28e6f248ba6d5f5f83137f6968d53982c428f55e2a8c6d4edfa810c60658?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth%3B+filename%3D%22yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth%22%3B&Expires=1709373140&Policy=&Signature=dCclVpWGw3B18uQ%7Efbx%7EfLn36A-wu0vS22e%7EMDBwnMJonyBKI-hKiEebOtTobKO23FPeplXgKRGcXneR2jvWnQ9weel5xFHqy-24dqrAstonBKkhYICmACZmoKqPW5uBmo9EKT9P69xdGJwksGZC29IiIB39QSpDnl%7E6N6D7Xnc3FwCVsKDxIgfRV64-qDzttoExm37RmST9XBYRh52kcgl4O9AaGZmFWJD-B0-dT3vCgwhX0gNyZJpsFn3G2omr1OEzvz90bilJhShQ2FlhRRJYpeCQ6SfzSqh28Nt3ysGpURd7DMt2IgKCf2u7dT7PkDOGA%7EwAxf%7EUZP3Ccg6GvA__&Key-Pair-Id=KCD77M1F0VK2B [following]
# --2024-02-28 09:52:20--  https://cdn-lfs-us-1.huggingface.co/repos/cc/e2/cce2cecbe61f2002bfd047dbb19558446e78db43c2b1c4a89071860f6eeb9a0e/c86e28e6f248ba6d5f5f83137f6968d53982c428f55e2a8c6d4edfa810c60658?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth%3B+filename%3D%22yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth%22%3B&Expires=1709373140&Policy=&Signature=dCclVpWGw3B18uQ%7Efbx%7EfLn36A-wu0vS22e%7EMDBwnMJonyBKI-hKiEebOtTobKO23FPeplXgKRGcXneR2jvWnQ9weel5xFHqy-24dqrAstonBKkhYICmACZmoKqPW5uBmo9EKT9P69xdGJwksGZC29IiIB39QSpDnl%7E6N6D7Xnc3FwCVsKDxIgfRV64-qDzttoExm37RmST9XBYRh52kcgl4O9AaGZmFWJD-B0-dT3vCgwhX0gNyZJpsFn3G2omr1OEzvz90bilJhShQ2FlhRRJYpeCQ6SfzSqh28Nt3ysGpURd7DMt2IgKCf2u7dT7PkDOGA%7EwAxf%7EUZP3Ccg6GvA__&Key-Pair-Id=KCD77M1F0VK2B
# Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 108.157.162.82, 108.157.162.85, 108.157.162.129, ...
# Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|108.157.162.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1235052641 (1.1G) [binary/octet-stream]
# Saving to: ‘yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth?download=true’
#
# yolow-v8_l_clipv2_f 100%[===================>]   1.15G   120MB/s    in 14s
#
# 2024-02-28 09:52:34 (83.5 MB/s) - ‘yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth?download=true’ saved [1235052641/1235052641]
#
# --2024-02-28 09:52:34--  https://huggingface.co/spaces/stevengrove/YOLO-World/resolve/main/configs/pretrain/yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py?download=true
# Resolving huggingface.co (huggingface.co)... 65.8.178.27, 65.8.178.12, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6247 (6.1K) [text/plain]
# Saving to: ‘yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py?download=true’
#
# yolo_world_l_t2i_bn 100%[===================>]   6.10K  --.-KB/s    in 0s
#
# 2024-02-28 09:52:35 (2.08 GB/s) - ‘yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py?download=true’ saved [6247/6247]
#
# --2024-02-28 09:52:35--  https://media.roboflow.com/notebooks/examples/dog.jpeg
# Resolving media.roboflow.com (media.roboflow.com)... 34.110.133.209
# Connecting to media.roboflow.com (media.roboflow.com)|34.110.133.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106055 (104K) [image/jpeg]
# Saving to: ‘dog.jpeg’
#
# dog.jpeg            100%[===================>] 103.57K  --.-KB/s    in 0.001s
#
# 2024-02-28 09:52:35 (82.4 MB/s) - ‘dog.jpeg’ saved [106055/106055]

# %%
import torch
from mmengine.config import Config
from mmengine.dataset import Compose
from mmengine.runner import Runner
from mmengine.runner.amp import autocast
from mmyolo.registry import RUNNERS
from torchvision.ops import nms

# %%
if __name__ == "__main__":
    # load config
    cfg = Config.fromfile(
        "/content/YOLO-World/configs/pretrain/yolo_world_l_t2i_bn_2e-4_100e_4x8gpus_obj365v1_goldg_train_lvis_minival.py"
    )
    cfg.work_dir = "."
    cfg.load_from = "yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth"
    runner = Runner.from_cfg(cfg)
    runner.call_hook("before_run")
    runner.load_or_resume()
    pipeline = cfg.test_dataloader.dataset.pipeline
    runner.pipeline = Compose(pipeline)
    runner.model.eval()
# Out:
# 02/28 09:52:49 - mmengine - WARNING - Failed to search registry with scope "mmyolo" in the "log_processor" registry tree. As a workaround, the current "log_processor" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmyolo" is a correct scope, or whether the registry is initialized.
# 02/28 09:52:49 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: False
#     MUSA available: False
#     numpy_random_seed: 771598735
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu121
#     OpenCV: 4.8.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 771598735
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/28 09:52:53 - mmengine - INFO - Config:
# _backend_args = None
# _multiscale_resize_transforms = [
#     dict(
#         transforms=[
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 320,
#                 320,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     320,
#                     320,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
#     dict(
#         transforms=[
#             dict(scale=(
#                 960,
#                 960,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     960,
#                     960,
#                 ),
#                 type='LetterResize'),
#         ],
#         type='Compose'),
# ]
# affine_scale = 0.9
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# backend_args = None
# base_lr = 0.002
# batch_shapes_cfg = None
# close_mosaic_epochs = 2
# coco_val_dataset = dict(
#     _delete_=True,
#     class_text_path='data/captions/lvis_v1_class_captions.json',
#     dataset=dict(
#         ann_file='annotations/lvis_v1_minival_inserted_image_name.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img=''),
#         data_root='data/lvis/',
#         test_mode=True,
#         type='YOLOv5LVISV1Dataset'),
#     pipeline=[
#         dict(backend_args=None, type='LoadImageFromFile'),
#         dict(scale=(
#             640,
#             640,
#         ), type='YOLOv5KeepRatioResize'),
#         dict(
#             allow_scale_up=False,
#             pad_val=dict(img=114),
#             scale=(
#                 640,
#                 640,
#             ),
#             type='LetterResize'),
#         dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#         dict(type='LoadText'),
#         dict(
#             meta_keys=(
#                 'img_id',
#                 'img_path',
#                 'ori_shape',
#                 'img_shape',
#                 'scale_factor',
#                 'pad_param',
#                 'texts',
#             ),
#             type='mmdet.PackDetInputs'),
#     ],
#     type='MultiModalDataset')
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
#     dict(
#         switch_epoch=98,
#         switch_pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=True,
#                 pad_val=dict(img=114.0),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_aspect_ratio=100,
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.09999999999999998,
#                     1.9,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 max_num_samples=80,
#                 num_neg_samples=(
#                     1203,
#                     1203,
#                 ),
#                 padding_to_max=True,
#                 padding_value='',
#                 type='RandomLoadText'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                     'texts',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='mmdet.PipelineSwitchHook'),
# ]
# custom_imports = dict(
#     allow_failed_imports=False, imports=[
#         'yolo_world',
#     ])
# data_root = 'data/coco/'
# dataset_type = 'YOLOv5CocoDataset'
# deepen_factor = 1.0
# default_hooks = dict(
#     checkpoint=dict(
#         interval=2,
#         max_keep_ckpts=2,
#         rule='greater',
#         save_best='auto',
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=100,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'mmyolo'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# flickr_train_dataset = dict(
#     ann_file='annotations/final_flickr_separateGT_train.json',
#     data_prefix=dict(img='images/'),
#     data_root='data/flickr/',
#     filter_cfg=dict(filter_empty_gt=True, min_size=32),
#     pipeline=[
#         dict(backend_args=None, type='LoadImageFromFile'),
#         dict(type='LoadAnnotations', with_bbox=True),
#         dict(
#             img_scale=(
#                 640,
#                 640,
#             ),
#             pad_val=114.0,
#             pre_transform=[
#                 dict(backend_args=None, type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations', with_bbox=True),
#             ],
#             type='MultiModalMosaic'),
#         dict(
#             border=(
#                 -320,
#                 -320,
#             ),
#             border_val=(
#                 114,
#                 114,
#                 114,
#             ),
#             max_aspect_ratio=100,
#             max_rotate_degree=0.0,
#             max_shear_degree=0.0,
#             scaling_ratio_range=(
#                 0.09999999999999998,
#                 1.9,
#             ),
#             type='YOLOv5RandomAffine'),
#         dict(
#             bbox_params=dict(
#                 format='pascal_voc',
#                 label_fields=[
#                     'gt_bboxes_labels',
#                     'gt_ignore_flags',
#                 ],
#                 type='BboxParams'),
#             keymap=dict(gt_bboxes='bboxes', img='image'),
#             transforms=[
#                 dict(p=0.01, type='Blur'),
#                 dict(p=0.01, type='MedianBlur'),
#                 dict(p=0.01, type='ToGray'),
#                 dict(p=0.01, type='CLAHE'),
#             ],
#             type='mmdet.Albu'),
#         dict(type='YOLOv5HSVRandomAug'),
#         dict(prob=0.5, type='mmdet.RandomFlip'),
#         dict(
#             max_num_samples=80,
#             num_neg_samples=(
#                 1203,
#                 1203,
#             ),
#             padding_to_max=True,
#             padding_value='',
#             type='RandomLoadText'),
#         dict(
#             meta_keys=(
#                 'img_id',
#                 'img_path',
#                 'ori_shape',
#                 'img_shape',
#                 'flip',
#                 'flip_direction',
#                 'texts',
#             ),
#             type='mmdet.PackDetInputs'),
#     ],
#     type='YOLOv5MixedGroundingDataset')
# img_scale = (
#     640,
#     640,
# )
# img_scales = [
#     (
#         640,
#         640,
#     ),
#     (
#         320,
#         320,
#     ),
#     (
#         960,
#         960,
#     ),
# ]
# last_stage_out_channels = 512
# last_transform = [
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# load_from = 'yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 7.5
# loss_cls_weight = 0.5
# loss_dfl_weight = 0.375
# lr_factor = 0.01
# max_aspect_ratio = 100
# max_epochs = 100
# max_keep_ckpts = 2
# mg_train_dataset = dict(
#     ann_file='annotations/final_mixed_train_no_coco.json',
#     data_prefix=dict(img='gqa/images/'),
#     data_root='data/mixed_grounding/',
#     filter_cfg=dict(filter_empty_gt=False, min_size=32),
#     pipeline=[
#         dict(backend_args=None, type='LoadImageFromFile'),
#         dict(type='LoadAnnotations', with_bbox=True),
#         dict(
#             img_scale=(
#                 640,
#                 640,
#             ),
#             pad_val=114.0,
#             pre_transform=[
#                 dict(backend_args=None, type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations', with_bbox=True),
#             ],
#             type='MultiModalMosaic'),
#         dict(
#             border=(
#                 -320,
#                 -320,
#             ),
#             border_val=(
#                 114,
#                 114,
#                 114,
#             ),
#             max_aspect_ratio=100,
#             max_rotate_degree=0.0,
#             max_shear_degree=0.0,
#             scaling_ratio_range=(
#                 0.09999999999999998,
#                 1.9,
#             ),
#             type='YOLOv5RandomAffine'),
#         dict(
#             bbox_params=dict(
#                 format='pascal_voc',
#                 label_fields=[
#                     'gt_bboxes_labels',
#                     'gt_ignore_flags',
#                 ],
#                 type='BboxParams'),
#             keymap=dict(gt_bboxes='bboxes', img='image'),
#             transforms=[
#                 dict(p=0.01, type='Blur'),
#                 dict(p=0.01, type='MedianBlur'),
#                 dict(p=0.01, type='ToGray'),
#                 dict(p=0.01, type='CLAHE'),
#             ],
#             type='mmdet.Albu'),
#         dict(type='YOLOv5HSVRandomAug'),
#         dict(prob=0.5, type='mmdet.RandomFlip'),
#         dict(
#             max_num_samples=80,
#             num_neg_samples=(
#                 1203,
#                 1203,
#             ),
#             padding_to_max=True,
#             padding_value='',
#             type='RandomLoadText'),
#         dict(
#             meta_keys=(
#                 'img_id',
#                 'img_path',
#                 'ori_shape',
#                 'img_shape',
#                 'flip',
#                 'flip_direction',
#                 'texts',
#             ),
#             type='mmdet.PackDetInputs'),
#     ],
#     type='YOLOv5MixedGroundingDataset')
# mixup_prob = 0.15
# model = dict(
#     backbone=dict(
#         image_model=dict(
#             act_cfg=dict(inplace=True, type='SiLU'),
#             arch='P5',
#             deepen_factor=1.0,
#             last_stage_out_channels=512,
#             norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#             type='YOLOv8CSPDarknet',
#             widen_factor=1.0),
#         text_model=dict(
#             frozen_modules=[
#                 'all',
#             ],
#             model_name='openai/clip-vit-base-patch32',
#             type='HuggingCLIPLanguageBackbone'),
#         type='MultiModalYOLOBackbone'),
#     bbox_head=dict(
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         head_module=dict(
#             act_cfg=dict(inplace=True, type='SiLU'),
#             embed_dims=512,
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 512,
#             ],
#             norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#             num_classes=80,
#             reg_max=16,
#             type='YOLOWorldHeadModule',
#             use_bn_head=True,
#             widen_factor=1.0),
#         loss_bbox=dict(
#             bbox_format='xyxy',
#             iou_mode='ciou',
#             loss_weight=7.5,
#             reduction='sum',
#             return_iou=False,
#             type='IoULoss'),
#         loss_cls=dict(
#             loss_weight=0.5,
#             reduction='none',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         loss_dfl=dict(
#             loss_weight=0.375,
#             reduction='mean',
#             type='mmdet.DistributionFocalLoss'),
#         prior_generator=dict(
#             offset=0.5, strides=[
#                 8,
#                 16,
#                 32,
#             ], type='mmdet.MlvlPointGenerator'),
#         type='YOLOWorldHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='YOLOWDetDataPreprocessor'),
#     mm_neck=True,
#     neck=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         block_cfg=dict(type='MaxSigmoidCSPLayerWithTwoConv'),
#         deepen_factor=1.0,
#         embed_channels=[
#             128,
#             256,
#             256,
#         ],
#         guide_channels=512,
#         in_channels=[
#             256,
#             512,
#             512,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=2,
#         num_heads=[
#             4,
#             8,
#             8,
#         ],
#         out_channels=[
#             256,
#             512,
#             512,
#         ],
#         type='YOLOWorldPAFPN',
#         widen_factor=1.0),
#     num_test_classes=1203,
#     num_train_classes=80,
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.7, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     train_cfg=dict(
#         assigner=dict(
#             alpha=0.5,
#             beta=6.0,
#             eps=1e-09,
#             num_classes=80,
#             topk=10,
#             type='BatchTaskAlignedAssigner',
#             use_ciou=True)),
#     type='YOLOWorldDetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.7, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_affine_transform = [
#     dict(
#         img_scale=(
#             640,
#             640,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -320,
#             -320,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.09999999999999998,
#             1.9,
#         ),
#         type='YOLOv5RandomAffine'),
# ]
# neck_embed_channels = [
#     128,
#     256,
#     256,
# ]
# neck_num_heads = [
#     4,
#     8,
#     8,
# ]
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 1203
# num_det_layers = 3
# num_training_classes = 80
# obj365v1_train_dataset = dict(
#     class_text_path='data/captions/obj365v1_class_captions.json',
#     dataset=dict(
#         ann_file='annotations/objects365_train.json',
#         data_prefix=dict(img='train/'),
#         data_root='data/objects365v1/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         type='YOLOv5Objects365V1Dataset'),
#     pipeline=[
#         dict(backend_args=None, type='LoadImageFromFile'),
#         dict(type='LoadAnnotations', with_bbox=True),
#         dict(
#             img_scale=(
#                 640,
#                 640,
#             ),
#             pad_val=114.0,
#             pre_transform=[
#                 dict(backend_args=None, type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations', with_bbox=True),
#             ],
#             type='MultiModalMosaic'),
#         dict(
#             border=(
#                 -320,
#                 -320,
#             ),
#             border_val=(
#                 114,
#                 114,
#                 114,
#             ),
#             max_aspect_ratio=100,
#             max_rotate_degree=0.0,
#             max_shear_degree=0.0,
#             scaling_ratio_range=(
#                 0.09999999999999998,
#                 1.9,
#             ),
#             type='YOLOv5RandomAffine'),
#         dict(
#             bbox_params=dict(
#                 format='pascal_voc',
#                 label_fields=[
#                     'gt_bboxes_labels',
#                     'gt_ignore_flags',
#                 ],
#                 type='BboxParams'),
#             keymap=dict(gt_bboxes='bboxes', img='image'),
#             transforms=[
#                 dict(p=0.01, type='Blur'),
#                 dict(p=0.01, type='MedianBlur'),
#                 dict(p=0.01, type='ToGray'),
#                 dict(p=0.01, type='CLAHE'),
#             ],
#             type='mmdet.Albu'),
#         dict(type='YOLOv5HSVRandomAug'),
#         dict(prob=0.5, type='mmdet.RandomFlip'),
#         dict(
#             max_num_samples=80,
#             num_neg_samples=(
#                 1203,
#                 1203,
#             ),
#             padding_to_max=True,
#             padding_value='',
#             type='RandomLoadText'),
#         dict(
#             meta_keys=(
#                 'img_id',
#                 'img_path',
#                 'ori_shape',
#                 'img_shape',
#                 'flip',
#                 'flip_direction',
#                 'texts',
#             ),
#             type='mmdet.PackDetInputs'),
#     ],
#     type='MultiModalDataset')
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=10.0),
#     constructor='YOLOWv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=16, lr=0.002, type='AdamW', weight_decay=0.025),
#     paramwise_cfg=dict(
#         bias_decay_mult=0.0,
#         custom_keys=dict({
#             'backbone.text_model': dict(lr_mult=0.01),
#             'logit_scale': dict(weight_decay=0.0)
#         }),
#         norm_decay_mult=0.0),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# resume = False
# save_epoch_intervals = 2
# strides = [
#     8,
#     16,
#     32,
# ]
# tal_alpha = 0.5
# tal_beta = 6.0
# tal_topk = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         class_text_path='data/captions/lvis_v1_class_captions.json',
#         dataset=dict(
#             ann_file='annotations/lvis_v1_minival_inserted_image_name.json',
#             batch_shapes_cfg=None,
#             data_prefix=dict(img=''),
#             data_root='data/lvis/',
#             test_mode=True,
#             type='YOLOv5LVISV1Dataset'),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(type='LoadText'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                     'texts',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='MultiModalDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/lvis/annotations/lvis_v1_minival_inserted_image_name.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.LVISMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#     dict(type='LoadText'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#             'texts',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# text_channels = 512
# text_transform = [
#     dict(
#         max_num_samples=80,
#         num_neg_samples=(
#             1203,
#             1203,
#         ),
#         padding_to_max=True,
#         padding_value='',
#         type='RandomLoadText'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#             'texts',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann_file = 'annotations/instances_train2017.json'
# train_batch_size_per_gpu = 16
# train_cfg = dict(
#     dynamic_intervals=[
#         (
#             98,
#             1,
#         ),
#     ],
#     max_epochs=100,
#     type='EpochBasedTrainLoop',
#     val_interval=10)
# train_data_prefix = 'train2017/'
# train_dataloader = dict(
#     batch_size=16,
#     collate_fn=dict(type='yolow_collate'),
#     dataset=dict(
#         datasets=[
#             dict(
#                 class_text_path='data/captions/obj365v1_class_captions.json',
#                 dataset=dict(
#                     ann_file='annotations/objects365_train.json',
#                     data_prefix=dict(img='train/'),
#                     data_root='data/objects365v1/',
#                     filter_cfg=dict(filter_empty_gt=False, min_size=32),
#                     type='YOLOv5Objects365V1Dataset'),
#                 pipeline=[
#                     dict(backend_args=None, type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                     dict(
#                         img_scale=(
#                             640,
#                             640,
#                         ),
#                         pad_val=114.0,
#                         pre_transform=[
#                             dict(backend_args=None, type='LoadImageFromFile'),
#                             dict(type='LoadAnnotations', with_bbox=True),
#                         ],
#                         type='MultiModalMosaic'),
#                     dict(
#                         border=(
#                             -320,
#                             -320,
#                         ),
#                         border_val=(
#                             114,
#                             114,
#                             114,
#                         ),
#                         max_aspect_ratio=100,
#                         max_rotate_degree=0.0,
#                         max_shear_degree=0.0,
#                         scaling_ratio_range=(
#                             0.09999999999999998,
#                             1.9,
#                         ),
#                         type='YOLOv5RandomAffine'),
#                     dict(
#                         bbox_params=dict(
#                             format='pascal_voc',
#                             label_fields=[
#                                 'gt_bboxes_labels',
#                                 'gt_ignore_flags',
#                             ],
#                             type='BboxParams'),
#                         keymap=dict(gt_bboxes='bboxes', img='image'),
#                         transforms=[
#                             dict(p=0.01, type='Blur'),
#                             dict(p=0.01, type='MedianBlur'),
#                             dict(p=0.01, type='ToGray'),
#                             dict(p=0.01, type='CLAHE'),
#                         ],
#                         type='mmdet.Albu'),
#                     dict(type='YOLOv5HSVRandomAug'),
#                     dict(prob=0.5, type='mmdet.RandomFlip'),
#                     dict(
#                         max_num_samples=80,
#                         num_neg_samples=(
#                             1203,
#                             1203,
#                         ),
#                         padding_to_max=True,
#                         padding_value='',
#                         type='RandomLoadText'),
#                     dict(
#                         meta_keys=(
#                             'img_id',
#                             'img_path',
#                             'ori_shape',
#                             'img_shape',
#                             'flip',
#                             'flip_direction',
#                             'texts',
#                         ),
#                         type='mmdet.PackDetInputs'),
#                 ],
#                 type='MultiModalDataset'),
#             dict(
#                 ann_file='annotations/final_flickr_separateGT_train.json',
#                 data_prefix=dict(img='images/'),
#                 data_root='data/flickr/',
#                 filter_cfg=dict(filter_empty_gt=True, min_size=32),
#                 pipeline=[
#                     dict(backend_args=None, type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                     dict(
#                         img_scale=(
#                             640,
#                             640,
#                         ),
#                         pad_val=114.0,
#                         pre_transform=[
#                             dict(backend_args=None, type='LoadImageFromFile'),
#                             dict(type='LoadAnnotations', with_bbox=True),
#                         ],
#                         type='MultiModalMosaic'),
#                     dict(
#                         border=(
#                             -320,
#                             -320,
#                         ),
#                         border_val=(
#                             114,
#                             114,
#                             114,
#                         ),
#                         max_aspect_ratio=100,
#                         max_rotate_degree=0.0,
#                         max_shear_degree=0.0,
#                         scaling_ratio_range=(
#                             0.09999999999999998,
#                             1.9,
#                         ),
#                         type='YOLOv5RandomAffine'),
#                     dict(
#                         bbox_params=dict(
#                             format='pascal_voc',
#                             label_fields=[
#                                 'gt_bboxes_labels',
#                                 'gt_ignore_flags',
#                             ],
#                             type='BboxParams'),
#                         keymap=dict(gt_bboxes='bboxes', img='image'),
#                         transforms=[
#                             dict(p=0.01, type='Blur'),
#                             dict(p=0.01, type='MedianBlur'),
#                             dict(p=0.01, type='ToGray'),
#                             dict(p=0.01, type='CLAHE'),
#                         ],
#                         type='mmdet.Albu'),
#                     dict(type='YOLOv5HSVRandomAug'),
#                     dict(prob=0.5, type='mmdet.RandomFlip'),
#                     dict(
#                         max_num_samples=80,
#                         num_neg_samples=(
#                             1203,
#                             1203,
#                         ),
#                         padding_to_max=True,
#                         padding_value='',
#                         type='RandomLoadText'),
#                     dict(
#                         meta_keys=(
#                             'img_id',
#                             'img_path',
#                             'ori_shape',
#                             'img_shape',
#                             'flip',
#                             'flip_direction',
#                             'texts',
#                         ),
#                         type='mmdet.PackDetInputs'),
#                 ],
#                 type='YOLOv5MixedGroundingDataset'),
#             dict(
#                 ann_file='annotations/final_mixed_train_no_coco.json',
#                 data_prefix=dict(img='gqa/images/'),
#                 data_root='data/mixed_grounding/',
#                 filter_cfg=dict(filter_empty_gt=False, min_size=32),
#                 pipeline=[
#                     dict(backend_args=None, type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                     dict(
#                         img_scale=(
#                             640,
#                             640,
#                         ),
#                         pad_val=114.0,
#                         pre_transform=[
#                             dict(backend_args=None, type='LoadImageFromFile'),
#                             dict(type='LoadAnnotations', with_bbox=True),
#                         ],
#                         type='MultiModalMosaic'),
#                     dict(
#                         border=(
#                             -320,
#                             -320,
#                         ),
#                         border_val=(
#                             114,
#                             114,
#                             114,
#                         ),
#                         max_aspect_ratio=100,
#                         max_rotate_degree=0.0,
#                         max_shear_degree=0.0,
#                         scaling_ratio_range=(
#                             0.09999999999999998,
#                             1.9,
#                         ),
#                         type='YOLOv5RandomAffine'),
#                     dict(
#                         bbox_params=dict(
#                             format='pascal_voc',
#                             label_fields=[
#                                 'gt_bboxes_labels',
#                                 'gt_ignore_flags',
#                             ],
#                             type='BboxParams'),
#                         keymap=dict(gt_bboxes='bboxes', img='image'),
#                         transforms=[
#                             dict(p=0.01, type='Blur'),
#                             dict(p=0.01, type='MedianBlur'),
#                             dict(p=0.01, type='ToGray'),
#                             dict(p=0.01, type='CLAHE'),
#                         ],
#                         type='mmdet.Albu'),
#                     dict(type='YOLOv5HSVRandomAug'),
#                     dict(prob=0.5, type='mmdet.RandomFlip'),
#                     dict(
#                         max_num_samples=80,
#                         num_neg_samples=(
#                             1203,
#                             1203,
#                         ),
#                         padding_to_max=True,
#                         padding_value='',
#                         type='RandomLoadText'),
#                     dict(
#                         meta_keys=(
#                             'img_id',
#                             'img_path',
#                             'ori_shape',
#                             'img_shape',
#                             'flip',
#                             'flip_direction',
#                             'texts',
#                         ),
#                         type='mmdet.PackDetInputs'),
#                 ],
#                 type='YOLOv5MixedGroundingDataset'),
#         ],
#         ignore_keys=[
#             'classes',
#             'palette',
#         ],
#         type='ConcatDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 8
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         img_scale=(
#             640,
#             640,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='MultiModalMosaic'),
#     dict(
#         border=(
#             -320,
#             -320,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.09999999999999998,
#             1.9,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         max_num_samples=80,
#         num_neg_samples=(
#             1203,
#             1203,
#         ),
#         padding_to_max=True,
#         padding_value='',
#         type='RandomLoadText'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#             'texts',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_pipeline_stage2 = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(scale=(
#         640,
#         640,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=True,
#         pad_val=dict(img=114.0),
#         scale=(
#             640,
#             640,
#         ),
#         type='LetterResize'),
#     dict(
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_aspect_ratio=100,
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.09999999999999998,
#             1.9,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         max_num_samples=80,
#         num_neg_samples=(
#             1203,
#             1203,
#         ),
#         padding_to_max=True,
#         padding_value='',
#         type='RandomLoadText'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#             'texts',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# tta_model = dict(
#     tta_cfg=dict(max_per_img=300, nms=dict(iou_threshold=0.65, type='nms')),
#     type='mmdet.DetTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             640,
#                             640,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 640,
#                                 640,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             320,
#                             320,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 320,
#                                 320,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#                 dict(
#                     transforms=[
#                         dict(scale=(
#                             960,
#                             960,
#                         ), type='YOLOv5KeepRatioResize'),
#                         dict(
#                             allow_scale_up=False,
#                             pad_val=dict(img=114),
#                             scale=(
#                                 960,
#                                 960,
#                             ),
#                             type='LetterResize'),
#                     ],
#                     type='Compose'),
#             ],
#             [
#                 dict(prob=1.0, type='mmdet.RandomFlip'),
#                 dict(prob=0.0, type='mmdet.RandomFlip'),
#             ],
#             [
#                 dict(type='mmdet.LoadAnnotations', with_bbox=True),
#             ],
#             [
#                 dict(
#                     meta_keys=(
#                         'img_id',
#                         'img_path',
#                         'ori_shape',
#                         'img_shape',
#                         'scale_factor',
#                         'pad_param',
#                         'flip',
#                         'flip_direction',
#                     ),
#                     type='mmdet.PackDetInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_ann_file = 'annotations/instances_val2017.json'
# val_batch_size_per_gpu = 1
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'val2017/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         class_text_path='data/captions/lvis_v1_class_captions.json',
#         dataset=dict(
#             ann_file='annotations/lvis_v1_minival_inserted_image_name.json',
#             batch_shapes_cfg=None,
#             data_prefix=dict(img=''),
#             data_root='data/lvis/',
#             test_mode=True,
#             type='YOLOv5LVISV1Dataset'),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(scale=(
#                 640,
#                 640,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='LetterResize'),
#             dict(_scope_='mmdet', type='LoadAnnotations', with_bbox=True),
#             dict(type='LoadText'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                     'texts',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='MultiModalDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/lvis/annotations/lvis_v1_minival_inserted_image_name.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.LVISMetric')
# val_interval_stage2 = 1
# val_num_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='mmdet.DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.025
# widen_factor = 1.0
# work_dir = '.'
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# 02/28 09:53:07 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/28 09:53:07 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by local backend from path: yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth
# 02/28 09:53:15 - mmengine - INFO - Load checkpoint from yolow-v8_l_clipv2_frozen_t2iv2_bn_o365_goldg_pretrain.pth

# %% [markdown]
# ### B-Box 검출 함수
# - class_names: 인식할 클래스 지정
# - return svimage[:, :, ::-1]: 이미지로 출력
# - return detections: bbox, confidensce 로 출력

# %%
import PIL.Image
import supervision as sv
import numpy as np

bounding_box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_position=sv.Position.CENTER)

class_names = ("face")

# class_names2 = ("person")

def run_image(
        runner,
        input_image,
        max_num_boxes=100,
        score_thr=0.05,
        nms_thr=0.5,
        output_image="output.png",
):
    global xyxy
    texts = [[t.strip()] for t in class_names.split(",")] + [[" "]]
    data_info = runner.pipeline(dict(img_id=0, img_path=input_image,
                                     texts=texts))

    data_batch = dict(
        inputs=data_info["inputs"].unsqueeze(0),
        data_samples=[data_info["data_samples"]],
    )

    with autocast(enabled=False), torch.no_grad():
        output = runner.model.test_step(data_batch)[0]
        runner.model.class_names = texts
        pred_instances = output.pred_instances

    keep_idxs = nms(pred_instances.bboxes, pred_instances.scores, iou_threshold=nms_thr)
    pred_instances = pred_instances[keep_idxs]
    pred_instances = pred_instances[pred_instances.scores.float() > score_thr]

    if len(pred_instances.scores) > max_num_boxes:
        indices = pred_instances.scores.float().topk(max_num_boxes)[1]
        pred_instances = pred_instances[indices]
    output.pred_instances = pred_instances

    pred_instances = pred_instances.cpu().numpy()
    detections = sv.Detections(
        xyxy=pred_instances['bboxes'],
        class_id=pred_instances['labels'],
        confidence=pred_instances['scores']
    )

    labels = [
        f"{class_id} {confidence:0.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    image = PIL.Image.open(input_image)
    svimage = np.array(image)
    svimage = bounding_box_annotator.annotate(svimage, detections)
    svimage = label_annotator.annotate(svimage, detections, labels)
    # return svimage[:, :, ::-1]
    return detections

# %% [markdown]
# ### xyxy만 출력
# - 위 디텍팅 함수에서 출력된 다양한 정보가 포함된 문자열을 [[xyxy], [xyxy]] 만 남게 전처리하는 코드
# - xyxy가 없을 시 또는 깨진 문자열로 출력되는 경우는 예외처리함

# %%
import numpy as np

def extract_xyxy(detections_str):

    # 'xyxy'의 시작과 끝 위치 찾기
    start_index = detections_str.find("xyxy=array([[") + len("xyxy=array([[")
    end_index = detections_str.find("]]")

    # 숫자 부분 추출
    xyxy_str = detections_str[start_index:end_index]

    # 문자열을 리스트로 분할합니다.
    boxes_str = xyxy_str.split("],\n       [")

    # 각 바운딩 박스 문자열을 좌표 리스트로 변환합니다.
    xyxy_list = []
    for box_str in boxes_str:
        coords = [float(coord.strip()) for coord in box_str.split(",")]
        xyxy_list.append(coords)

    return xyxy_list

# %% [markdown]
# ### 스타 이름 인덱스화

# %%
import csv

star_names = {}

with open("/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/스타 이미지 데이터/스타 수집 대상 - 시트1.csv", mode="r", encoding="utf-8") as inp:
    reader = csv.reader(inp)
    star_names = {rows[3]: rows[0] for rows in reader}
    del star_names['검색어']

print(star_names)
# Out:
# {'라이즈 원빈': '0', '차은우': '1', '라이즈 앤톤': '2', '라이즈 성찬': '3', '슈퍼주니어 규현': '4', '라이즈 소희': '5', '하이라이트 이기광': '6', '라이즈 은석': '7', '워너원 박지훈': '8', '방탄소년단 지민': '9', '라이즈 쇼타로': '10', '강다니엘': '11', '엑소 백현': '12', '세븐틴 원우': '13', '세븐틴 민규': '14', '세븐틴 정한': '15', '더보이즈 에릭': '16', '방탄소년단 정국': '17', '방탄소년단 뷔': '18', '슈퍼주니어 희철': '19', '워너원 황민현': '20', '동방신기 최강창민': '21', '세븐틴 조슈아': '22', '세븐틴 에스쿱스': '23', '방탄소년단 RM': '24', '워너원 김재환': '25', '더보이즈 주연': '26', '동방신기 유노윤호': '27', '샤이니 키': '28', '세븐틴 도겸': '29', '세븐틴 우지': '30', '방탄소년단 진': '31', '세븐틴 호시': '32', '세븐틴 승관': '33', '세븐틴 준': '34', '세븐틴 디노': '35', 'NCT 도영': '36', 'NCT 재현': '37', '세븐틴 디에잇': '38', '방탄소년단 제이홉': '39', '방탄소년단 슈가': '40', '세븐틴 버논': '41', 'NCT 마크': '42', '더보이즈 선우': '43', '옹성우': '44', '송민호': '45', '더보이즈 현재': '46', 'NCT 해찬': '47', '하이라이트 윤두준': '48', 'NCT 정우': '49', '위너 김진우': '50', '제로베이스원 성한빈': '51', '슈퍼주니어 시원': '52', '슈퍼주니어 동해': '53', '샤이니 민호': '54', 'NCT 태용': '55', '투모로우바이투게더 연준': '56', '더보이즈 영훈': '57', '비투비 이창섭': '58', '투모로우바이투게더 수빈': '59', '샤이니 태민': '60', '위너 이승훈': '61', 'NCT 지성': '62', '샤이니 온유': '63', 'NCT 재민': '64', '엔하이픈 성훈': '65', '빅뱅 대성': '66', '하이라이트 양요섭': '67', '슈퍼주니어 은혁': '68', '슈퍼주니어 이특': '69', '슈퍼주니어 신동': '70', 'NCT 런쥔': '71', 'NCT 제노': '72', '투모로우바이투게더 범규': '73', '워너원 배진영': '74', 'NCT 텐': '75', '비투비 서은광': '76', 'NCT 태일': '77', '슈퍼주니어 예성': '78', '스트레이 키즈': '79', '스트레이키즈 현진': '80', '몬스타엑스 민혁': '81', '비투비 임현식': '82', '투모로우바이투게더 태현': '83', '비투비 이민혁': '84', '펜타곤 후이': '85', 'B1A4 산들': '86', '위너 강승윤': '87', '더보이즈 큐': '88', '제로베이스원 장하오': '89', '슈퍼주니어 려욱': '90', '투모로우바이투게더 휴닝카이': '91', '제로베이스원 한유진': '92', '워너원 이대휘': '93', '에이티즈 산': '94', '몬스타엑스 아이엠': '95', '인피니트 김성규': '96', '제로베이스원 석매튜': '97', '제로베이스원 리키': '98', 'B1A4 공찬': '99', '소녀시대 태연': '100', '블랙핑크 제니': '101', '트와이스 지효': '102', '뉴진스 하니': '103', '블랙핑크 지수': '104', '아이브 장원영': '105', '에스파 카리나': '106', '뉴진스 해린': '107', '에스파 윈터': '108', '레드벨벳 웬디': '109', '오마이걸 미미': '110', '레드벨벳 슬기': '111', '여자아이들 미연': '112', '르세라핌 카즈하': '113', '트와이스 나연': '114', '뉴진스 다니엘': '115', '뉴진스 혜인': '116', '아이브 가을': '117', '블랙핑크 리사': '118', '레드벨벳 조이': '119', '르세라핌 허윤진': '120', '블랙핑크 로제': '121', '트와이스 사나': '122', '오마이걸 유아': '123', '트와이스 미나': '124', '르세라핌 김채원': '125', '뉴진스 민지': '126', '소녀시대 윤아': '127', '소녀시대 서현': '128', '레드벨벳 예리': '129', '아이브 이서': '130', '오마이걸 아린': '131', 'EXID 하니': '132', '시그니처 지원': '133', '여자아이들 우기': '134', '르세라핌 홍은채': '135', '마마무 화사': '136', '엔믹스 설윤': '137', '아이브 리즈': '138', '레드벨벳 아이린': '139', '에스파 지젤': '140', '에스파 닝닝': '141', '트와이스 채영': '142', '에이핑크 정은지': '143', 'ITZY 유나': '144', '여자아이들 소연': '145', '트와이스 다현': '146', '소녀시대 유리': '147', '르세라핌 사쿠라': '148', '오마이걸 효정': '149', '마마무 솔라': '150', '걸스데이 혜리': '151', '우주소녀 설아': '152', '아이브 안유진': '153', '트와이스 정연': '154', '소녀시대 수영': '155', '우주소녀 여름': '156', '걸스데이 민아': '157', '엔믹스 지우': '158', '오마이걸 승희': '159', 'ITZY 리아': '160', '엔믹스 해원': '161', '에이핑크 박초롱': '162', '아이브 레이': '163', '걸스데이 소진': '164', '오마이걸 유빈': '165', '에이핑크 김남주': '166', '소녀시대 써니': '167', '우주소녀 수빈': '168', '걸스데이 유라': '169', 'ITZY 예지': '170', '마마무 휘인': '171', '소녀시대 효연': '172', '프로미스나인 백지헌': '173', '우주소녀 보나': '174', '우주소녀 다영': '175', 'ITZY 류진': '176', '엔믹스 규진': '177', '에이핑크 윤보미': '178', '하이키 리이나': '179', '우아 나나': '180', '하이키 서이': '181', '에이핑크 오하영': '182', '프로미스나인 이채영': '183', 'ITZY 채령': '184', '우주소녀 연정': '185', '프로미스나인 이나경': '186', '하이키 옐': '187', '우아 우연': '188', '프로미스나인 박지원': '189', '프로미스나인 노지선': '190', '러블리즈 유지애': '191', '다이아 정채연': '192', '프로미스나인 이새롬': '193', '에프엑스 루나': '194', '프로미스나인 송하영': '195', '프로미스나인 이서연': '196', '클라씨 보은': '197', '스테이씨 시은': '198', '위키미키 최유정': '199', '손흥민': '200', '임영웅': '201', '아이유': '202', '신혜선': '203', '김유정': '204', '송강': '205', '유재석': '206', '이찬원': '207', '한소희': '208', '정우성': '209'}

# %% [markdown]
# ### 전체 이미지 B-Box 검출 후 .txt 파일 저장
# - xyxy -> 상대좌표화된 xywh 으로 변경

# %%
import re
import os
import numpy as np
from unicodedata import normalize

folder_path = '/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/스타 이미지 데이터/resized'

for label in os.listdir(folder_path):
    sub_path = folder_path+'/'+label+'/' # /content/resized/naver_트와이스 지효/
    label_name = normalize('NFC', label[6:]) # naver_트와이스 지효 -> 트와이스 지효
    star_index = int(star_names[label_name]) # 트와이스 지효 -> 0

    for filename in os.listdir(sub_path):
        if 'jpg' in filename:
          img = run_image(runner, sub_path+filename) # /content/resized/naver_트와이스 지효/167.jpg
          input_string = str(img)
          bbox_txt = ''

          try:
            number_list = extract_xyxy(input_string) # [x,y,x,y]
            for i in range(len(number_list)):
              # Calculate x center, y center
              x_center = ((number_list[i][0] + number_list[i][2]) / 2) / 640
              y_center = ((number_list[i][1] + number_list[i][3]) / 2) / 640

              # Calculate width and height
              width = (number_list[i][2] - number_list[i][0]) / 640
              height = (number_list[i][3] - number_list[i][1]) / 640
              bbox_txt += f"{star_index} {x_center} {y_center} {width} {height}\n"

            txt_path = sub_path + filename[:-4] + '.txt' # 파일명.txt 로 같은 폴더에 저장
            with open(txt_path, "w") as file:
                file.write(bbox_txt)
                file.close()
          except ValueError:
            continue

print("Bounding boxes saved to bounding_boxes.txt")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Bounding boxes saved to bounding_boxes.txt

# %%
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# random_star = random.choice(resized_star)
# idx = random.randint(0, 500)

# **Assumptions**
image_file = f"/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/스타 이미지 데이터/resized/naver_블랙핑크 제니/245_1.jpg"   # Replace with your image filename
label_file = f"/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/스타 이미지 데이터/resized/naver_블랙핑크 제니/245_1.txt"

# **1. Read the label data**
with open(label_file, "r") as f:
    for line in f:
        data = line.strip().split()
        label = data[0]
        x_center = float(data[1])
        y_center = float(data[2])
        width = float(data[3])
        height = float(data[4])

# **2. Load the image**
image = cv2.imread(image_file)

# **3. Calculate bounding box coordinates**
x_min = int(x_center - (width / 2)) * 640
y_min = int(y_center - (height / 2)) * 640
x_max = int(x_center + (width / 2)) * 640
y_max = int(y_center + (height / 2)) * 640

# **4. Draw the bounding box and label**
cv2.rectangle(image, (x_min, y_min), (x_max, y_max), color=(0, 255, 0), thickness=2)  # Green color

# Select a font (This might require installing a font or using a default path)
# font_path = '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf'
# font = ImageFont.truetype(font_path, size=16)

# Use PIL to add text (OpenCV's text rendering can be less flexible)
image_pil = Image.fromarray(image)
draw = ImageDraw.Draw(image_pil)
draw.text((x_min, y_min - 20), label, fill=(0, 255, 0, 255))  # Green color
image = cv2.cvtColor(np.array(image_pil), cv2.COLOR_RGB2BGR)

# **5. Display the image in Jupyter Notebook**
plt.figure(figsize=(10, 8))  # Adjust figure size as needed
plt.imshow(image)
plt.show()
