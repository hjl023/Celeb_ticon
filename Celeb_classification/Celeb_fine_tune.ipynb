# %%
! pip install ultralytics
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = YOLO('/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/yolov8s.pt')
# Resume training
results = model.train(data='/content/drive/MyDrive/객체인식_3조/스타 얼굴 인식 모델/stardata.yaml',epochs=5, imgsz=640, batch=8) # 이어서 학습
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (AMD EPYC 7B12)
# ...

# %%
import shutil

shutil.make_archive('/content/star_runs2', 'zip', '/content/runs')
# Out:
# '/content/star_runs2.zip'
