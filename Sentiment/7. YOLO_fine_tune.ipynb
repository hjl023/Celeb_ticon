# %%
! gdown 1-UgeFwUWes4WuZCMcMd5GIFKZDRf4fn5 # 데이터 다운 감정 단일라벨
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-UgeFwUWes4WuZCMcMd5GIFKZDRf4fn5
# From (redirected): https://drive.google.com/uc?id=1-UgeFwUWes4WuZCMcMd5GIFKZDRf4fn5&confirm=t&uuid=10c6495f-812f-41ec-8af9-4a1bc0829874
# To: /content/data3.zip
# 100% 2.28G/2.28G [00:19<00:00, 117MB/s]

# %%
# ! gdown 1LnwRfPT0P_iEr-puxEAv0kp5-6Cr0sBx #yaml 한글 파일 다운

# %%
! gdown 1y4YlZVWLtv6fmqbV5cCBHnU0wv6lounZ #yaml 영어 파일 다운
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1y4YlZVWLtv6fmqbV5cCBHnU0wv6lounZ
# To: /content/mydata_eng.yaml
# 100% 203/203 [00:00<00:00, 1.28MB/s]

# %%
! unzip '/content/data3.zip' #
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: data2/labels/val/5499.txt
#   inflating: data2/labels/val/55.txt
#   inflating: data2/labels/val/550.txt
#   inflating: data2/labels/val/5500.txt
#   inflating: data2/labels/val/5501.txt
#   inflating: data2/labels/val/5502.txt
#   inflating: data2/labels/val/5503.txt
#   inflating: data2/labels/val/5504.txt
#   inflating: data2/labels/val/5505.txt
#   inflating: data2/labels/val/5506.txt
#   inflating: data2/labels/val/5507.txt
#   inflating: data2/labels/val/5508.txt
#   inflating: data2/labels/val/5509.txt
#   inflating: data2/labels/val/551.txt
#   inflating: data2/labels/val/5510.txt
#   inflating: data2/labels/val/5511.txt
#   inflating: data2/labels/val/5512.txt
#   inflating: data2/labels/val/5513.txt
#   inflating: data2/labels/val/5514.txt
#   inflating: data2/labels/val/5515.txt
#   inflating: data2/labels/val/5516.txt
#   inflating: data2/labels/val/5517.txt
#   inflating: data2/labels/val/5518.txt
# ...

# %%
! pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 16.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! gdown 1--TPXddtpQDmKrMUYLPaqIKvylxIBJdP #이전 학습 train 결과
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1--TPXddtpQDmKrMUYLPaqIKvylxIBJdP
# From (redirected): https://drive.google.com/uc?id=1--TPXddtpQDmKrMUYLPaqIKvylxIBJdP&confirm=t&uuid=66d0de6d-ab45-4dbc-aaca-baedaa0cbd94
# To: /content/x_15runs.zip
# 100% 775M/775M [00:10<00:00, 75.8MB/s]

# %%
! unzip '/content/x_15runs.zip'
# Out:
# Archive:  /content/x_15runs.zip
#    creating: detect/
#    creating: detect/train/
#    creating: detect/train2/
#    creating: detect/train3/
#    creating: detect/train3/weights/
#   inflating: detect/train3/P_curve.png
#   inflating: detect/train3/train_batch1.jpg
#   inflating: detect/train3/confusion_matrix_normalized.png
#   inflating: detect/train3/R_curve.png
#   inflating: detect/train3/results.csv
#   inflating: detect/train3/labels.jpg
#   inflating: detect/train3/results.png
#   inflating: detect/train3/val_batch0_labels.jpg
#   inflating: detect/train3/PR_curve.png
#   inflating: detect/train3/val_batch2_pred.jpg
#   inflating: detect/train3/val_batch0_pred.jpg
#   inflating: detect/train3/train_batch2.jpg
#   inflating: detect/train3/val_batch1_labels.jpg
#   inflating: detect/train3/confusion_matrix.png
#   inflating: detect/train3/events.out.tfevents.1708831596.4faf1016a9c4.3312.2
#   inflating: detect/train3/val_batch1_pred.jpg
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/last.pt')
# Resume training
results = model.train(data='/content/mydata_eng.yaml',epochs=5, imgsz=640, batch=16,device=0) # 이어서 학
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
import shutil

shutil.make_archive('/content/x_25runs', 'zip', '/content/runs')
# Out:
# '/content/x_25runs.zip'
